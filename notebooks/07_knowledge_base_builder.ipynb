# %%
import json

# %%
with open("../artifacts/documents.json", "r", encoding="utf-8") as f:
    iot23_docs = json.load(f)

print(len(iot23_docs))
# Out:
# 1008748

# %%
with open("../artifacts/variot_vulnerabilities.json", "r", encoding="utf-8") as f:
    variot_vulns = json.load(f)

print(len(variot_vulns))
# Out:
# 5

# %%
with open("../artifacts/variot_exploits.json", "r", encoding="utf-8") as f:
    variot_exploits = json.load(f)

print(len(variot_exploits))
# Out:
# 10

# %%
with open("../artifacts/mitre_documents.json", "r", encoding="utf-8") as f:
    mitre_docs = json.load(f)

print(len(mitre_docs))
# Out:
# 2051

# %%
from rag_icot.components.knowledge_base_builder import KnowledgeBaseBuilder

kb = KnowledgeBaseBuilder()

# %%
iot23 = kb.load_documents(
    "../artifacts/iot23_knowledge.json"
)

mitre = kb.load_documents(
    "../artifacts/mitre_knowledge.json"
)

variot = kb.load_documents(
    "../artifacts/variot_knowledge.json"
)
