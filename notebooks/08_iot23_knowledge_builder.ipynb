# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(project_root)
# Out:
# e:\ICOT-RAG

# %%
print(os.getcwd())
# Out:
# e:\ICOT-RAG\notebooks

# %%
import sys

for p in sys.path:
    print(p)
# Out:
# e:\ICOT-RAG
# C:\Users\Hp\AppData\Local\Programs\Python\Python312\python312.zip
# C:\Users\Hp\AppData\Local\Programs\Python\Python312\DLLs
# C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib
# C:\Users\Hp\AppData\Local\Programs\Python\Python312
# e:\ICOT-RAG\venv
#
# e:\ICOT-RAG\venv\Lib\site-packages

# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(project_root)
# Out:
# e:\ICOT-RAG

# %%
from rag_icot.components.data_ingestion import DataIngestion

print("Imported Successfully")
# Out:
# Imported Successfully

# %%
print(os.path.exists("../rag_icot"))
print(os.path.exists("../rag_icot/components"))
print(os.path.exists("../rag_icot/components/data_ingestion.py"))
# Out:
# True
# True
# True

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# e:\ICOT-RAG\notebooks
# ['01_data_exploration.ipynb', '02_data_ingestion_test.ipynb', '03_document_generation.ipynb', '04_variot_exploration.ipynb', '04_variot_test.ipynb', '05_variot_exploits.ipynb', '06_mitre_integration.ipynb', '07_knowledge_base_builder.ipynb', '08_iot23_knowledge_builder.ipynb']

# %%
import os
import sys

# Go one level up from notebooks -> ICOT-RAG
project_root = os.path.abspath("..")

# Add project root to Python path
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(project_root)
# Out:
# e:\ICOT-RAG

# %%
from rag_icot.components.data_ingestion import DataIngestion

loader = DataIngestion()

print(dir(loader))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'load_all_iot23', 'load_iot23']

# %%
from rag_icot.components.data_ingestion import DataIngestion

loader = DataIngestion()

df = loader.load_all_iot23("../datasets/iot23")

print(df.shape)
# Out:
# Loading CTU-Honeypot-Capture-4-1
# Loading CTU-Honeypot-Capture-5-1
# Loading CTU-IoT-Malware-Capture-1-1
# Loading CTU-IoT-Malware-Capture-17-1
# Loading CTU-IoT-Malware-Capture-21-1
# Loading CTU-IoT-Malware-Capture-3-1
# Loading CTU-IoT-Malware-Capture-7-1
# Loading CTU-IoT-Malware-Capture-8-1
# Loading CTU-IoT-Malware-Capture-9-1
# (73673228, 24)

# %%
print(df["label"].value_counts())
# Out:
# label
# Malicious    73062197
# Benign         609205
# benign           1826
# Name: count, dtype: int64

# %%
df["label"] = df["label"].str.lower()

print(df["label"].value_counts())
# Out:
# label
# malicious    73062197
# benign         611031
# Name: count, dtype: int64

# %%
print(df.shape)

print(df["label"].value_counts())

print(df["detailed-label"].value_counts())

print(df["scenario"].value_counts())
# Out:
# (73673228, 24)
# label
# malicious    73062197
# benign         611031
# Name: count, dtype: int64
# detailed-label
# PartOfAHorizontalPortScan           34351994
# Okiru                               24988612
# DDoS                                13694756
# -                                     611031
# C&C-HeartBeat                          12612
# C&C                                     8238
# Attack                                  5966
# C&C-Torii                                 14
# PartOfAHorizontalPortScan-Attack           5
# Name: count, dtype: int64
# scenario
# CTU-IoT-Malware-Capture-17-1    54659855
# CTU-IoT-Malware-Capture-7-1     11454714
# CTU-IoT-Malware-Capture-9-1      6378293
# CTU-IoT-Malware-Capture-1-1      1008748
# CTU-IoT-Malware-Capture-3-1       156103
# CTU-IoT-Malware-Capture-8-1        10403
# CTU-IoT-Malware-Capture-21-1        3286
# CTU-Honeypot-Capture-5-1            1374
# CTU-Honeypot-Capture-4-1             452
# Name: count, dtype: int64

# %%
from rag_icot.components.iot23_knowledge_builder import IoT23KnowledgeBuilder

builder = IoT23KnowledgeBuilder()

builder.build(df)
# Out:
# [{'id': 'iot23_-',
#   'source': 'IoT23',
#   'attack_type': '-',
#   'summary': '- consists of 611031 network flows. It primarily uses the UDP protocol. The most common service is -. It was observed in 9 scenario(s).',
#   'flow_count': 611031,
#   'protocol_distribution': {'udp': 513886, 'tcp': 61116, 'icmp': 36029},
#   'service_distribution': {'-': 594723,
#    'dns': 15709,
#    'http': 269,
#    'dhcp': 163,
#    'ssl': 86,
#    'ssh': 81},
#   'connection_state_distribution': {'S0': 533244,
#    'OTH': 36066,
#    'SF': 24278,
#    'REJ': 7945,
#    'RSTOS0': 6265,
#    'RSTO': 1525,
#    'RSTRH': 1294,
#    'RSTR': 148,
#    'SH': 121,
#    'S1': 54,
#    'S2': 50,
#    'S3': 27,
#    'SHR': 14},
#   'average_duration': 1.6035,
#   'average_orig_bytes': 26.1,
#   'average_resp_bytes': 567.2,
#   'unique_source_ips': 35720,
#   'unique_destination_ips': 496315,
#   'scenarios': ['CTU-Honeypot-Capture-4-1',
#    'CTU-Honeypot-Capture-5-1',
#    'CTU-IoT-Malware-Capture-1-1',
#    'CTU-IoT-Malware-Capture-17-1',
#    'CTU-IoT-Malware-Capture-21-1',
#    'CTU-IoT-Malware-Capture-3-1',
#    'CTU-IoT-Malware-Capture-7-1',
#    'CTU-IoT-Malware-Capture-8-1',
#    'CTU-IoT-Malware-Capture-9-1']},
#  {'id': 'iot23_attack',
#   'source': 'IoT23',
#   'attack_type': 'Attack',
#   'summary': 'Attack consists of 5966 network flows. It primarily uses the TCP protocol. The most common service is ssh. It was observed in 2 scenario(s).',
#   'flow_count': 5966,
#   'protocol_distribution': {'tcp': 5966},
#   'service_distribution': {'ssh': 5818, '-': 147, 'http': 1},
#   'connection_state_distribution': {'SF': 5962, 'RSTO': 3, 'S2': 1},
#   'average_duration': 4.3854,
#   'average_orig_bytes': 576.33,
#   'average_resp_bytes': 1835.6,
#   'unique_source_ips': 3,
#   'unique_destination_ips': 223,
#   'scenarios': ['CTU-IoT-Malware-Capture-17-1',
#    'CTU-IoT-Malware-Capture-3-1']},
#  {'id': 'iot23_candc',
#   'source': 'IoT23',
#   'attack_type': 'C&C',
#   'summary': 'C&C consists of 8238 network flows. It primarily uses the TCP protocol. The most common service is -. It was observed in 3 scenario(s).',
#   'flow_count': 8238,
#   'protocol_distribution': {'tcp': 8230, 'udp': 8},
#   'service_distribution': {'-': 8232, 'irc': 6},
#   'connection_state_distribution': {'S0': 8231,
#    'S1': 4,
#    'RSTR': 1,
#    'RSTO': 1,
#    'SF': 1},
#   'average_duration': 15.998,
#   'average_orig_bytes': 1.11,
#   'average_resp_bytes': 1.77,
#   'unique_source_ips': 3,
#   'unique_destination_ips': 15,
#   'scenarios': ['CTU-IoT-Malware-Capture-1-1',
#    'CTU-IoT-Malware-Capture-3-1',
#    'CTU-IoT-Malware-Capture-8-1']},
#  {'id': 'iot23_candc-heartbeat',
#   'source': 'IoT23',
#   'attack_type': 'C&C-HeartBeat',
#   'summary': 'C&C-HeartBeat consists of 12612 network flows. It primarily uses the TCP protocol. The most common service is -. It was observed in 2 scenario(s).',
#   'flow_count': 12612,
#   'protocol_distribution': {'tcp': 12612},
#   'service_distribution': {'-': 12612},
#   'connection_state_distribution': {'S0': 9233,
#    'REJ': 3361,
#    'OTH': 10,
#    'SF': 6,
#    'S1': 1,
#    'SHR': 1},
#   'average_duration': 4.7242,
#   'average_orig_bytes': 0.13,
#   'average_resp_bytes': 0.13,
#   'unique_source_ips': 2,
#   'unique_destination_ips': 2,
#   'scenarios': ['CTU-IoT-Malware-Capture-17-1',
#    'CTU-IoT-Malware-Capture-7-1']},
#  {'id': 'iot23_candc-torii',
#   'source': 'IoT23',
#   'attack_type': 'C&C-Torii',
#   'summary': 'C&C-Torii consists of 14 network flows. It primarily uses the TCP protocol. The most common service is -. It was observed in 1 scenario(s).',
#   'flow_count': 14,
#   'protocol_distribution': {'tcp': 14},
#   'service_distribution': {'-': 14},
#   'connection_state_distribution': {'S0': 10,
#    'SF': 1,
#    'REJ': 1,
#    'S2': 1,
#    'S1': 1},
#   'average_duration': 6130.3628,
#   'average_orig_bytes': 3096.79,
#   'average_resp_bytes': 3096.79,
#   'unique_source_ips': 1,
#   'unique_destination_ips': 1,
#   'scenarios': ['CTU-IoT-Malware-Capture-21-1']},
#  {'id': 'iot23_ddos',
#   'source': 'IoT23',
#   'attack_type': 'DDoS',
#   'summary': 'DDoS consists of 13694756 network flows. It primarily uses the TCP protocol. The most common service is -. It was observed in 2 scenario(s).',
#   'flow_count': 13694756,
#   'protocol_distribution': {'tcp': 13655172, 'udp': 39584},
#   'service_distribution': {'-': 13694756},
#   'connection_state_distribution': {'S0': 13694091, 'REJ': 660, 'RSTO': 5},
#   'average_duration': 0.0178,
#   'average_orig_bytes': 1.37,
#   'average_resp_bytes': 0.0,
#   'unique_source_ips': 2,
#   'unique_destination_ips': 11959049,
#   'scenarios': ['CTU-IoT-Malware-Capture-17-1',
#    'CTU-IoT-Malware-Capture-7-1']},
#  {'id': 'iot23_okiru',
#   'source': 'IoT23',
#   'attack_type': 'Okiru',
#   'summary': 'Okiru consists of 24988612 network flows. It primarily uses the TCP protocol. The most common service is -. It was observed in 2 scenario(s).',
#   'flow_count': 24988612,
#   'protocol_distribution': {'tcp': 24988612},
#   'service_distribution': {'-': 24988612},
#   'connection_state_distribution': {'S0': 24975868,
#    'REJ': 12395,
#    'RSTO': 301,
#    'RSTR': 15,
#    'RSTOS0': 13,
#    'S2': 10,
#    'OTH': 3,
#    'S1': 3,
#    'SF': 2,
#    'SH': 2},
#   'average_duration': 0.0003,
#   'average_orig_bytes': 0.0,
#   'average_resp_bytes': 0.0,
#   'unique_source_ips': 2,
#   'unique_destination_ips': 23234999,
#   'scenarios': ['CTU-IoT-Malware-Capture-17-1',
#    'CTU-IoT-Malware-Capture-7-1']},
#  {'id': 'iot23_partofahorizontalportscan',
#   'source': 'IoT23',
#   'attack_type': 'PartOfAHorizontalPortScan',
#   'summary': 'PartOfAHorizontalPortScan consists of 34351994 network flows. It primarily uses the TCP protocol. The most common service is -. It was observed in 4 scenario(s).',
#   'flow_count': 34351994,
#   'protocol_distribution': {'tcp': 34351968, 'udp': 26},
#   'service_distribution': {'-': 34348756, 'http': 3238},
#   'connection_state_distribution': {'S0': 34339155,
#    'SF': 7277,
#    'REJ': 3918,
#    'RSTR': 1459,
#    'RSTO': 47,
#    'RSTRH': 45,
#    'S2': 37,
#    'S1': 25,
#    'SH': 22,
#    'RSTOS0': 9},
#   'average_duration': 0.0242,
#   'average_orig_bytes': 0.01,
#   'average_resp_bytes': 0.06,
#   'unique_source_ips': 3,
#   'unique_destination_ips': 31405689,
#   'scenarios': ['CTU-IoT-Malware-Capture-1-1',
#    'CTU-IoT-Malware-Capture-17-1',
#    'CTU-IoT-Malware-Capture-3-1',
#    'CTU-IoT-Malware-Capture-9-1']},
#  {'id': 'iot23_partofahorizontalportscan-attack',
#   'source': 'IoT23',
#   'attack_type': 'PartOfAHorizontalPortScan-Attack',
#   'summary': 'PartOfAHorizontalPortScan-Attack consists of 5 network flows. It primarily uses the TCP protocol. The most common service is -. It was observed in 1 scenario(s).',
#   'flow_count': 5,
#   'protocol_distribution': {'tcp': 5},
#   'service_distribution': {'-': 5},
#   'connection_state_distribution': {'S0': 5},
#   'average_duration': 3.1308,
#   'average_orig_bytes': 0.0,
#   'average_resp_bytes': 0.0,
#   'unique_source_ips': 1,
#   'unique_destination_ips': 1,
#   'scenarios': ['CTU-IoT-Malware-Capture-17-1']}]

# %%
from rag_icot.components.iot23_knowledge_builder import IoT23KnowledgeBuilder

builder = IoT23KnowledgeBuilder()

knowledge = builder.build(df)

print(len(knowledge))
# Out:
# 9

# %%
from rag_icot.components.knowledge_base_builder import KnowledgeBaseBuilder
kb = KnowledgeBaseBuilder()

# %%
knowledge[0]
# Out:
# {'id': 'iot23_-',
#  'source': 'IoT23',
#  'attack_type': '-',
#  'summary': '- consists of 611031 network flows. It primarily uses the UDP protocol. The most common service is -. It was observed in 9 scenario(s).',
#  'flow_count': 611031,
#  'protocol_distribution': {'udp': 513886, 'tcp': 61116, 'icmp': 36029},
#  'service_distribution': {'-': 594723,
#   'dns': 15709,
#   'http': 269,
#   'dhcp': 163,
#   'ssl': 86,
#   'ssh': 81},
#  'connection_state_distribution': {'S0': 533244,
#   'OTH': 36066,
#   'SF': 24278,
#   'REJ': 7945,
#   'RSTOS0': 6265,
#   'RSTO': 1525,
#   'RSTRH': 1294,
#   'RSTR': 148,
#   'SH': 121,
#   'S1': 54,
#   'S2': 50,
#   'S3': 27,
#   'SHR': 14},
#  'average_duration': 1.6035,
#  'average_orig_bytes': 26.1,
#  'average_resp_bytes': 567.2,
#  'unique_source_ips': 35720,
#  'unique_destination_ips': 496315,
#  'scenarios': ['CTU-Honeypot-Capture-4-1',
#   'CTU-Honeypot-Capture-5-1',
#   'CTU-IoT-Malware-Capture-1-1',
#   'CTU-IoT-Malware-Capture-17-1',
#   'CTU-IoT-Malware-Capture-21-1',
#   'CTU-IoT-Malware-Capture-3-1',
#   'CTU-IoT-Malware-Capture-7-1',
#   'CTU-IoT-Malware-Capture-8-1',
#   'CTU-IoT-Malware-Capture-9-1']}

# %%
kb.save_documents(
    knowledge,
    "../artifacts/iot23_knowledge.json"
)
# Out:
# Saved 9 documents to ../artifacts/iot23_knowledge.json
