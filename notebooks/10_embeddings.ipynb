# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.append(project_root)

print(project_root)
# Out:
# e:\ICOT-RAG

# %%
from rag_icot.components.knowledge_base_builder import KnowledgeBaseBuilder

kb = KnowledgeBaseBuilder()

master_documents = kb.load_documents(
    "../artifacts/master_documents.json"
)

print(len(master_documents))
# Out:
# 2115

# %%
from rag_icot.components.embedding_builder import EmbeddingBuilder

builder = EmbeddingBuilder()
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
text = master_documents[0].get(
    "description",
    master_documents[0].get("summary", "")
)

embedding = builder.embed(text)

print(type(embedding))
print(embedding.shape)
# Out:
# <class 'numpy.ndarray'>
# (384,)

# %%
print(master_documents[0].keys())
# Out:
# dict_keys(['id', 'source', 'attack_type', 'summary', 'flow_count', 'protocol_distribution', 'service_distribution', 'connection_state_distribution', 'average_duration', 'average_orig_bytes', 'average_resp_bytes', 'unique_source_ips', 'unique_destination_ips', 'scenarios'])

# %%
import importlib
import rag_icot.components.embedding_builder as eb

importlib.reload(eb)

builder = eb.EmbeddingBuilder()
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
embeddings = builder.embed_documents(
    master_documents
)

print(len(embeddings))
# Out:
# 2115

# %%
for i, doc in enumerate(master_documents):

    if "description" not in doc and "summary" not in doc:
        print(i)
        print(doc)
        break
