# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from rag_icot.pipeline.rag_icot_pipeline import RAGICOTPipeline
# Out:
# e:\ICOT-RAG\rag_icot\components\llm.py:3: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
pipeline = RAGICOTPipeline()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
answer = pipeline.run(
    "How can I protect my IoT network from Mirai botnet attacks?"
)
# Out:
# Iteration 1
# {"thought": "The current knowledge provides examples of vulnerabilities (command injection in routers) that *could* be exploited by a botnet like Mirai. However, it does not provide direct information about Mirai's specific infection vectors (e.g., brute-forcing default credentials, known CVEs it exploits), its operational mechanisms, or general protection strategies against it. To answer how to protect an IoT network from Mirai, I need to understand Mirai's common attack methods and common protective measures.", "retrieve": true, "search_query": "Mirai botnet attack vectors and protection strategies"}
# Searching: Mirai botnet attack vectors and protection strategies
#
# Iteration 2
# {
#     "thought": "The current knowledge provides general information about botnets, C2 encryption, and a couple of router command injection vulnerabilities. However, it does not specifically detail how Mirai botnet attacks operate (e.g., its primary infection vectors, specific vulnerabilities it exploited beyond the general examples), nor does it offer concrete protective measures against Mirai. To answer 'How can I protect my IoT network from Mirai botnet attacks?', I need information on Mirai's specific infection methods, the types of vulnerabilities it targeted, and recommended prevention strategies.",
#     "retrieve": true,
#     "search_query": "Mirai botnet infection methods exploited vulnerabilities prevention"
# }
# Searching: Mirai botnet infection methods exploited vulnerabilities prevention
#
# Iteration 3
# {"thought": "I have examples of vulnerabilities in routers that could be exploited, and a general description of botnets. However, to provide specific protection advice against Mirai, I need to understand Mirai's specific attack vectors, common vulnerabilities it targets, how it spreads, and its typical infection process.", "retrieve": true, "search_query": "Mirai botnet attack vectors common vulnerabilities spreading mechanism"}
# Searching: Mirai botnet attack vectors common vulnerabilities spreading mechanism

# %%
print(answer)
# Out:
# ## 1. Executive Summary
#
# Protection against Mirai botnet attacks, as suggested by the provided evidence, requires addressing fundamental security weaknesses in IoT devices, particularly routers. These vulnerabilities include command injection flaws in web interfaces and command-line tools, unauthenticated access to critical device settings, and the use of weak default credentials. Exploitation of such vulnerabilities allows adversaries to gain root access, alter configurations like DNS settings, and deploy malicious payloads to form a botnet capable of performing activities such as Distributed Denial of Service (DDoS).
#
# ## 2. Threat Description
#
# Adversaries compromise numerous third-party systems to form botnets, which are networks of compromised systems instructed to perform coordinated tasks. These botnets can be used for activities such as large-scale Distributed Denial of Service (DDoS). The attacks leverage specific vulnerabilities in IoT devices, primarily routers, to achieve unauthorized access and control.
#
# Common exploitation vectors identified include:
# *   **Command Injection:** Exploiting command injection vulnerabilities in router web interfaces (e.g., `dnslookup.cgi` in Netgear DGN2200) or through limited command-line tools (e.g., `ping` command in Huawei HG532n's ATP tool) to gain a root shell or execute arbitrary commands.
# *   **Unauthenticated Remote Access:** Exploiting web interfaces that are accessible without authentication to modify critical device settings, such as DNS servers (e.g., UTstarcom WA3002G4, D-Link ADSL DSL-2640U). This can redirect users to malicious sites, replace ads, control network traffic, and push additional malware.
# *   **Telnet Port Exposure:** Utilizing limited web interface access to expose traditionally filtered ports like Telnet to the outside world through NAT port-forwarding, enabling further exploitation.
# *   **Payload Delivery:** After gaining initial access, adversaries can download and execute malicious payloads (e.g., `linux/mipsbe/mettle_reverse_tcp` using `wget`) to establish persistence and incorporate the device into a botnet.
#
# Adversaries may also conceal command and control (C2) traffic using encryption algorithms, which could be vulnerable to reverse engineering if secret keys are poorly handled within malware samples or configuration files.
#
# ## 3. Supporting Evidence
#
# *   **Huawei HG532n Command Injection**: A Metasploit module details exploitation of a command injection vulnerability in Huawei HG532n routers. This allows gaining a root shell by leveraging a "limited" user login to expose the router's telnet port, then injecting commands into the ATP's hidden "ping" command. The module specifies the use of a `linux/mipsbe/mettle_reverse_tcp` payload, downloaded via `wget`, and includes steps to expose and hide the telnet port.
# *   **Netgear DGN2200 dnslookup.cgi Command Injection (CVE-2017-6334)**: Another Metasploit module describes a command injection vulnerability in NETGEAR DGN2200v1/v2/v3/v4 routers. This exploit requires valid login details and injects commands through the `host_name` parameter in the `dnslookup.cgi` page.
# *   **UTstarcom WA3002G4 Unauthenticated Remote DNS Change Exploit**: A script demonstrates an unauthenticated remote DNS change vulnerability in the UTstarcom WA3002G4 router. The web interface, accessible without authentication, allows adversaries to modify primary and secondary DNS servers, leading to redirection to malicious sites, ad replacement, network traffic control, and the pushing of additional malware.
# *   **D-Link ADSL DSL-2640U IM_1.00 Unauthenticated Remote DNS Change Exploit**: Similar to the UTstarcom exploit, this script targets the D-Link ADSL DSL-2640U router, exploiting an unauthenticated web interface vulnerability to change DNS settings with similar malicious outcomes.
# *   **Botnet Formation Description**: "Adversaries may compromise numerous third-party systems to form a botnet that can be used during targeting... With a botnet at their disposal, adversaries may perform follow-on activity such as large-scale ... Distributed Denial of Service (DDoS)."
# *   **C2 Encryption**: "Adversaries may employ an encryption algorithm to conceal command and control traffic... implementations may be vulnerable to reverse engineering if secret keys are encoded and/or generated within malware samples/configuration files."
#
# ## 4. MITRE ATT&CK Mapping
#
# The described attack vectors and objectives align with the following MITRE ATT&CK techniques:
#
# *   **Initial Access**:
#     *   Exploit Public-Facing Application (T1190): Exploiting vulnerabilities in router web interfaces (e.g., Huawei HG532n, Netgear DGN2200, UTstarcom WA3002G4, D-Link DSL-2640U) accessible from the internet.
# *   **Execution**:
#     *   Command and Scripting Interpreter (T1059): Executing arbitrary commands on devices through command injection (e.g., `ping` command injection, `dnslookup.cgi` host_name parameter).
# *   **Privilege Escalation**:
#     *   Exploitation for Privilege Escalation (T1068): Gaining a root shell on compromised devices (e.g., Huawei HG532n exploit).
# *   **Persistence**:
#     *   Modify Authentication Process (T1098.005): Potentially establishing persistent access by modifying authentication details after gaining control.
#     *   Scheduled Task/Job (T1053): Likely used by malware to maintain presence, though not explicitly detailed in the command injection exploits.
# *   **Defense Evasion**:
#     *   Obfuscated Files or Information (T1027): Command injection often requires obfuscation (e.g., `command.gsub!(/\s/, '${IFS}')` mentioned in Huawei exploit).
# *   **Command and Control**:
#     *   Application Layer Protocol (T1071): Communication over HTTP for web interface access and Telnet for command-line access.
#     *   Ingress Tool Transfer (T1105): Downloading malicious payloads onto the device (e.g., using `wget` to fetch `linux/mipsbe/mettle_reverse_tcp` payload).
#     *   Encryption (T1573): Concealing C2 traffic, though noted as potentially vulnerable to reverse engineering.
# *   **Impact**:
#     *   Distributed Denial of Service (T1498): Explicitly mentioned as a follow-on activity for botnets.
#
# ## 5. Related Vulnerabilities
#
# *   **Huawei HG532n Command Injection**: A command injection vulnerability enabling root shell access via the web interface and telnet port exposure.
# *   **Netgear DGN2200 dnslookup.cgi Command Injection (CVE-2017-6334)**: A command injection flaw in the `dnslookup.cgi` page of NETGEAR DGN2200 series routers, requiring valid login credentials.
# *   **UTstarcom WA3002G4 Unauthenticated Remote DNS Change**: A vulnerability in the web interface allowing unauthenticated modification of DNS server settings.
# *   **D-Link ADSL DSL-2640U IM_1.00 Unauthenticated Remote DNS Change**: A vulnerability in the web interface allowing unauthenticated modification of DNS server settings.
# *   **Weak Cryptography Implementation**: Implementations of encryption algorithms for C2 may be vulnerable to reverse engineering if secret keys are encoded or generated within malware samples/configuration files.
#
# ## 6. Recommended Mitigations
#
# Based on the evidence provided, the following mitigations are recommended to protect IoT networks from Mirai-like botnet attacks:
#
# *   **Vulnerability and Patch Management**:
#     *   Regularly update device firmware to patch known command injection vulnerabilities (e.g., CVE-2017-6334) and other security flaws in router web interfaces and command-line tools.
#     *   Ensure all applications and services on IoT devices are securely coded, with robust input validation to prevent command injection.
# *   **Strong Authentication**:
#     *   Implement and enforce strong, unique passwords for all administrative interfaces, including web logins and Telnet. Avoid default or easily guessable credentials.
#     *   Require authentication for all critical configuration changes, particularly those accessible via web interfaces (e.g., DNS settings).
# *   **Network Segmentation and Access Control**:
#     *   Restrict external access to administrative interfaces (e.g., Telnet, SSH, web management) to trusted networks or IP addresses only. Disable unnecessary port forwarding of such services to the internet.
#     *   Ensure that internal services like Telnet are not easily exposed through NAT port-forwarding without explicit, secure configuration.
# *   **Secure Configuration**:
#     *   Review and secure router configurations to prevent unauthenticated modification of critical settings, such as DNS servers.
#     *   Disable unnecessary services and features on IoT devices to reduce the attack surface.
# *   **Execution Prevention and Monitoring**:
#     *   Implement controls to prevent arbitrary command execution and unauthorized payload downloads (e.g., blocking `wget` requests from internal devices to suspicious external sources, if possible, through network egress filtering).
#     *   Monitor network traffic for anomalous activities, such as unusual outbound connections or attempts to download executable files.
# *   **Secure C2 Implementation**:
#     *   For any device or C2 communication that uses encryption, ensure that secret keys are securely generated, stored, and managed, making them resistant to reverse engineering from malware samples or configuration files.
#
# ## 7. References
#
# *   Metasploit Module: Huawei HG532n Command Injection
# *   Metasploit Module: Netgear DGN2200 dnslookup.cgi Command Injection (CVE-2017-6334)
# *   Exploit Script: UTstarcom WA3002G4 Unauthenticated Remote DNS Change Exploit
# *   Exploit Script: D-Link ADSL DSL-2640U IM_1.00 Unauthenticated Remote DNS Change Exploit
# *   General MITRE ATT&CK Description: "Adversaries may compromise numerous third-party systems to form a botnet..."
# *   General MITRE ATT&CK Description: "Adversaries may employ an encryption algorithm to conceal command and control traffic..."
