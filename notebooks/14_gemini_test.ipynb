# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from rag_icot.components.llm import GeminiLLM
# Out:
# e:\ICOT-RAG\rag_icot\components\llm.py:3: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
llm = GeminiLLM()

# %%
response = llm.generate(
    "What is a DDoS attack?"
)

print(response)
# Out:
# A **DDoS attack** (Distributed Denial of Service attack) is a malicious attempt to disrupt the normal traffic of a targeted server, service, or network by overwhelming it with a flood of internet traffic.
#
# Here's a breakdown of what that means:
#
# 1.  **Denial of Service (DoS):**
#     *   The core goal is to make a service unavailable to its intended users. Imagine a popular website, an online game server, or even an internal company network.
#     *   A DoS attack tries to "deny service" by overwhelming the target with too many requests, too much data, or exploiting a vulnerability that crashes the service.
#
# 2.  **Distributed (D):**
#     *   This is the key differentiator for a **DDoS** attack. Instead of a single source trying to overwhelm the target, a DDoS attack uses *multiple* compromised computer systems (often thousands or even millions) as sources of attack traffic.
#     *   These compromised devices form what's known as a **botnet**. Each device in the botnet is called a "bot" or "zombie," and they are often infected with malware that allows an attacker (the "bot herder") to control them remotely without the owners' knowledge.
#
# **How a DDoS Attack Works:**
#
# 1.  **Infection:** Attackers infect many computers, smart devices (IoT devices), or servers with malware, turning them into "bots."
# 2.  **Command and Control:** The attacker establishes a "command and control" (C2) server that can send instructions to all the bots in the botnet.
# 3.  **Launch:** The attacker instructs the botnet to simultaneously send massive amounts of traffic (requests, data packets, malformed data) to the target's IP address.
# 4.  **Overwhelm:** The target server, network, or application becomes overloaded with this flood of illegitimate traffic. It can't process all the requests, its bandwidth is consumed, or its resources (CPU, memory) are exhausted.
# 5.  **Denial of Service:** Legitimate users can no longer access the service because it's too slow, unresponsive, or crashes entirely.
#
# **Analogy:**
#
# Imagine a popular shop (the target server).
# *   **DoS:** One person stands in the doorway, blocking legitimate customers from entering. The shop can deal with this relatively easily.
# *   **DDoS:** Thousands of people, coordinated by a single leader (the attacker), simultaneously flood all entrances, phone lines, and even the delivery dock. The shop's staff (server resources) are completely overwhelmed, and no real customers can get in or out.
#
# **Motivations Behind DDoS Attacks:**
#
# *   **Extortion:** Demanding payment to stop the attack.
# *   **Activism/Hacktivism:** Protesting against an organization or government.
# *   **Competition:** Disrupting a competitor's online business.
# *   **Vandalism/Revenge:** Pure malice or personal vendettas.
# *   **Distraction:** Using a DDoS attack as a smokescreen for other malicious activities, like data breaches.
#
# **Impacts of a DDoS Attack:**
#
# *   **Financial Loss:** Lost sales, recovery costs, damage to equipment.
# *   **Reputational Damage:** Loss of customer trust, brand erosion.
# *   **Operational Disruption:** Inability to perform business functions.
# *   **Security Risk:** Can hide more sophisticated attacks.
#
# DDoS attacks are a significant threat because they are difficult to fully prevent (due to their distributed nature) and require sophisticated defenses to mitigate.
