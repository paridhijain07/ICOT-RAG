# %%
import os
import sys

# This line tells Python to look outside the 'notebooks' folder
sys.path.append(os.path.abspath(os.path.join("..")))

# Now try importing your class again
from rag_icot.components.data_ingestion import DataIngestion

# %%
loader = DataIngestion()

# %%
df = loader.load_iot23(
    r"../datasets/iot23/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled"
)

# %%
print(df.shape)
# Out:
# (452, 23)

# %%
df.head()
# Out:
#                   ts                 uid      id.orig_h id.orig_p  \
# 0  1540469302.538640  CGm6jB4dXK71ZDWUDh  192.168.1.132     58687
# 1  1540469197.400159  CnaDAG3n5r8eiG4su2  192.168.1.132      1900
# 2  1540469385.734089  CUrxU238nt0m6yTgKf  192.168.1.132     32893
# 3  1540469831.302625  CGQf8t1kjdxB5PHXL4  192.168.1.132     53395
# 4  1540469831.265405  CUo9DH2QDnCaBIGjkg  192.168.1.132     52801
#
#          id.resp_h id.resp_p proto service    duration orig_bytes  ...  \
# 0     216.239.35.4       123   udp       -    0.114184         48  ...
# 1  239.255.255.250      1900   udp       -  160.367579       7536  ...
# 2     216.239.35.8       123   udp       -    0.016986         48  ...
# 3       2.16.60.82       443   tcp       -    0.003497          0  ...
# 4      192.168.1.1        53   udp     dns    0.036724         34  ...
#
#   local_resp missed_bytes history orig_pkts orig_ip_bytes resp_pkts  \
# 0          -            0      Dd         1            76         1
# ...
