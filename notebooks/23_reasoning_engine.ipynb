# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import importlib

import rag_icot.components.reasoning_engine as re

importlib.reload(re)
# Out:
# e:\ICOT-RAG\rag_icot\components\llm.py:3: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# <module 'rag_icot.components.reasoning_engine' from 'e:\\ICOT-RAG\\rag_icot\\components\\reasoning_engine.py'>

# %%
engine = re.ReasoningEngine()
# Out:
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
result = engine.reason(
    "How can I protect my IoT devices from Mirai botnet attacks?"
)
# Out:
# ...
# Iteration 1
# ...
# Thought: The user is asking for protection methods against Mirai botnet attacks on IoT devices. The provided evidence contains information about various malware (Socksbot, iKitten, Linux Rabbit, Amadey) and specific vulnerabilities in ASUS routers. While the ASUS router vulnerabilities (CVE-2017-5891, CVE-2017-5892) highlight issues like default credentials and unpatched firmware which are common vectors for IoT malware like Mirai, the evidence does not explicitly mention Mirai, its specific attack vectors, or comprehensive protective measures against it. Linux Rabbit targets IoT devices but for cryptocurrency mining, not DDoS like Mirai. Therefore, the current evidence is insufficient to directly answer the question about protecting against Mirai botnet attacks.
# Confidence: 0.9
# Enough Information: False
# ...

# %%
documents = result["documents"]

trace = result["trace"]

# %%
print(len(documents))
# Out:
# 6

# %%
for step in trace:

    print("=" * 80)

    print("Iteration:", step["iteration"])

    print("Thought:", step["thought"])

    print("Confidence:", step["confidence"])

    print("Enough Information:", step["enough_information"])

    print("Reason:", step["reason"])

    print("Missing Information:", step["missing_information"])

    print("Search Query:", step["search_query"])

    print("Retrieved Documents:", step["retrieved_document_count"])

    print("Document IDs:")

    for doc_id in step["retrieved_document_ids"]:

        print("   •", doc_id)
# Out:
# ...
# Iteration: 1
# Thought: The user is asking for protection methods against Mirai botnet attacks on IoT devices. The provided evidence contains information about various malware (Socksbot, iKitten, Linux Rabbit, Amadey) and specific vulnerabilities in ASUS routers. While the ASUS router vulnerabilities (CVE-2017-5891, CVE-2017-5892) highlight issues like default credentials and unpatched firmware which are common vectors for IoT malware like Mirai, the evidence does not explicitly mention Mirai, its specific attack vectors, or comprehensive protective measures against it. Linux Rabbit targets IoT devices but for cryptocurrency mining, not DDoS like Mirai. Therefore, the current evidence is insufficient to directly answer the question about protecting against Mirai botnet attacks.
# Confidence: 0.9
# Enough Information: False
# ...
